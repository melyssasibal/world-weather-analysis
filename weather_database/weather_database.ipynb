# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
cities

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except (KeyError):
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | provideniya
# Processing Record 3 of Set 1 | colares
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | airai
# Processing Record 6 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | balaguer
# Processing Record 9 of Set 1 | san patricio
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | huayapam
# City not found. Skipping...
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | emba
# Processing Record 17 of Set 1 | talnakh
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | qujing
# Processing Record 20 of Set 1 | shelburne
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | bonavista
# Processing Record 24 of Set 1 | san vicente
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | vanimo
# Processing Record 27 of Set 1 | miri
# Processing Record 28 of Set 1 | amboasary
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | banda aceh
# Processing Record 31 of Set 1 | margate
# Processing Record 32 of Set 1 | wanning
# Processing Record 33 of Set 1 | nouadhibou
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | watford
# Processing Record 36 of Set 1 | nemuro
# Processing Record 37 of Set 1 | mandi bahauddin
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | malumfashi
# Processing Record 40 of Set 1 | souillac
# Processing Record 41 of Set 1 | cap malheureux
# Processing Record 42 of Set 1 | sambava
# Processing Record 43 of Set 1 | ahipara
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | kishorganj
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | turayf
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | smithers
# Processing Record 3 of Set 2 | maine-soroa
# Processing Record 4 of Set 2 | sola
# Processing Record 5 of Set 2 | ixtapa
# Processing Record 6 of Set 2 | kahului
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 9 of Set 2 | saint-pierre
# Processing Record 10 of Set 2 | salalah
# Processing Record 11 of Set 2 | dicabisagan
# Processing Record 12 of Set 2 | carnarvon
# Processing Record 13 of Set 2 | danilov
# Processing Record 14 of Set 2 | payson
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | mandera
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | pozo colorado
# Processing Record 20 of Set 2 | rikitea
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | tessalit
# Processing Record 24 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | bintulu
# Processing Record 27 of Set 2 | kiama
# Processing Record 28 of Set 2 | vila velha
# Processing Record 29 of Set 2 | roma
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 2 | vyssi brod
# Processing Record 34 of Set 2 | coquimbo
# Processing Record 35 of Set 2 | bandarbeyla
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 2 | norman wells
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | lethem
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | lagoa
# Processing Record 43 of Set 2 | kandrian
# Processing Record 44 of Set 2 | hermanus
# Processing Record 45 of Set 2 | hovd
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | nong bua
# Processing Record 48 of Set 2 | lavrentiya
# Processing Record 49 of Set 2 | pisco
# Processing Record 50 of Set 2 | saint george
# Processing Record 1 of Set 3 | okha
# Processing Record 2 of Set 3 | esperance
# Processing Record 3 of Set 3 | cabo san lucas
# Processing Record 4 of Set 3 | priladozhskiy
# Processing Record 5 of Set 3 | paramonga
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | beyneu
# Processing Record 8 of Set 3 | dunedin
# Processing Record 9 of Set 3 | podor
# Processing Record 10 of Set 3 | fort wellington
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | podporozhye
# Processing Record 13 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 3 | cidreira
# Processing Record 15 of Set 3 | simao
# Processing Record 16 of Set 3 | aykhal
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | akyab
# Processing Record 19 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 3 | popondetta
# Processing Record 21 of Set 3 | bitung
# Processing Record 22 of Set 3 | tocache
# Processing Record 23 of Set 3 | rocha
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | harper
# Processing Record 26 of Set 3 | mendi
# Processing Record 27 of Set 3 | atuona
# Processing Record 28 of Set 3 | qaqortoq
# Processing Record 29 of Set 3 | luau
# Processing Record 30 of Set 3 | bahia honda
# Processing Record 31 of Set 3 | houma
# Processing Record 32 of Set 3 | guane
# Processing Record 33 of Set 3 | wamba
# Processing Record 34 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 3 | khatanga
# Processing Record 36 of Set 3 | bathsheba
# Processing Record 37 of Set 3 | palmer
# Processing Record 38 of Set 3 | ilulissat
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | avera
# Processing Record 41 of Set 3 | besenyszog
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | biltine
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | fortuna
# Processing Record 47 of Set 3 | pevek
# Processing Record 48 of Set 3 | vershino-darasunskiy
# Processing Record 49 of Set 3 | altay
# Processing Record 50 of Set 3 | nova londrina
# Processing Record 1 of Set 4 | nancha
# Processing Record 2 of Set 4 | nazareno etla
# Processing Record 3 of Set 4 | burica
# City not found. Skipping...
# Processing Record 4 of Set 4 | katsuura
# Processing Record 5 of Set 4 | geraldton
# Processing Record 6 of Set 4 | havelock
# Processing Record 7 of Set 4 | iquitos
# Processing Record 8 of Set 4 | vanavara
# Processing Record 9 of Set 4 | atar
# Processing Record 10 of Set 4 | mount isa
# Processing Record 11 of Set 4 | bolgatanga
# Processing Record 12 of Set 4 | chokurdakh
# Processing Record 13 of Set 4 | seddon
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | chipinge
# Processing Record 16 of Set 4 | chagoda
# Processing Record 17 of Set 4 | port lincoln
# Processing Record 18 of Set 4 | tarko-sale
# Processing Record 19 of Set 4 | puerto ayora
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | hasaki
# Processing Record 22 of Set 4 | khovu-aksy
# Processing Record 23 of Set 4 | gari
# Processing Record 24 of Set 4 | yellowknife
# Processing Record 25 of Set 4 | severo-kurilsk
# Processing Record 26 of Set 4 | abu kamal
# Processing Record 27 of Set 4 | guilin
# Processing Record 28 of Set 4 | mehtar lam
# Processing Record 29 of Set 4 | hobart
# Processing Record 30 of Set 4 | gasa
# Processing Record 31 of Set 4 | dikson
# Processing Record 32 of Set 4 | anchorage
# Processing Record 33 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 4 | vrnograc
# Processing Record 35 of Set 4 | hokitika
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | bilma
# Processing Record 38 of Set 4 | panlaitan
# Processing Record 39 of Set 4 | road town
# Processing Record 40 of Set 4 | sao filipe
# Processing Record 41 of Set 4 | guerrero negro
# Processing Record 42 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 43 of Set 4 | bluff
# Processing Record 44 of Set 4 | castro
# Processing Record 45 of Set 4 | oksfjord
# Processing Record 46 of Set 4 | zalantun
# Processing Record 47 of Set 4 | sao felix do xingu
# Processing Record 48 of Set 4 | berlevag
# Processing Record 49 of Set 4 | djambala
# Processing Record 50 of Set 4 | saint-philippe
# Processing Record 1 of Set 5 | kavieng
# Processing Record 2 of Set 5 | upington
# Processing Record 3 of Set 5 | belaya gora
# Processing Record 4 of Set 5 | pangnirtung
# Processing Record 5 of Set 5 | leh
# Processing Record 6 of Set 5 | gizo
# Processing Record 7 of Set 5 | upernavik
# Processing Record 8 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 5 | husavik
# Processing Record 10 of Set 5 | cherskiy
# Processing Record 11 of Set 5 | samarai
# Processing Record 12 of Set 5 | sulphur
# Processing Record 13 of Set 5 | liwale
# Processing Record 14 of Set 5 | tuktoyaktuk
# Processing Record 15 of Set 5 | elizabeth city
# Processing Record 16 of Set 5 | hobyo
# Processing Record 17 of Set 5 | shchebetovka
# Processing Record 18 of Set 5 | weiser
# Processing Record 19 of Set 5 | spornoye
# Processing Record 20 of Set 5 | bulawayo
# Processing Record 21 of Set 5 | valdez
# Processing Record 22 of Set 5 | codrington
# Processing Record 23 of Set 5 | pacific grove
# Processing Record 24 of Set 5 | bambous virieux
# Processing Record 25 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 5 | emirdag
# Processing Record 27 of Set 5 | isangel
# Processing Record 28 of Set 5 | poum
# Processing Record 29 of Set 5 | port macquarie
# Processing Record 30 of Set 5 | bayir
# Processing Record 31 of Set 5 | hienghene
# Processing Record 32 of Set 5 | dingle
# Processing Record 33 of Set 5 | leshukonskoye
# Processing Record 34 of Set 5 | omsukchan
# Processing Record 35 of Set 5 | vardo
# Processing Record 36 of Set 5 | camanducaia
# Processing Record 37 of Set 5 | gamba
# Processing Record 38 of Set 5 | jutai
# Processing Record 39 of Set 5 | kirakira
# Processing Record 40 of Set 5 | grand-santi
# Processing Record 41 of Set 5 | vallenar
# Processing Record 42 of Set 5 | qinzhou
# Processing Record 43 of Set 5 | belyy yar
# Processing Record 44 of Set 5 | port augusta
# Processing Record 45 of Set 5 | port-cartier
# Processing Record 46 of Set 5 | debre tabor
# Processing Record 47 of Set 5 | great yarmouth
# Processing Record 48 of Set 5 | garowe
# Processing Record 49 of Set 5 | port shepstone
# Processing Record 50 of Set 5 | baruun-urt
# Processing Record 1 of Set 6 | yafran
# Processing Record 2 of Set 6 | leningradskiy
# Processing Record 3 of Set 6 | pulivendla
# Processing Record 4 of Set 6 | riverton
# Processing Record 5 of Set 6 | ayan
# Processing Record 6 of Set 6 | ternate
# Processing Record 7 of Set 6 | praia da vitoria
# Processing Record 8 of Set 6 | mahebourg
# Processing Record 9 of Set 6 | asfi
# Processing Record 10 of Set 6 | lunino
# Processing Record 11 of Set 6 | nieuwpoort
# Processing Record 12 of Set 6 | axim
# Processing Record 13 of Set 6 | sistranda
# Processing Record 14 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 6 | pingzhuang
# Processing Record 16 of Set 6 | bauska
# Processing Record 17 of Set 6 | pierre
# Processing Record 18 of Set 6 | sabha
# Processing Record 19 of Set 6 | bethel
# Processing Record 20 of Set 6 | rodino
# Processing Record 21 of Set 6 | san quintin
# Processing Record 22 of Set 6 | haines junction
# Processing Record 23 of Set 6 | perth
# Processing Record 24 of Set 6 | zhigansk
# Processing Record 25 of Set 6 | charlestown
# Processing Record 26 of Set 6 | manavgat
# Processing Record 27 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 6 | kysyl-syr
# Processing Record 29 of Set 6 | liku
# Processing Record 30 of Set 6 | ribeira grande
# Processing Record 31 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 6 | amancio
# City not found. Skipping...
# Processing Record 33 of Set 6 | omboue
# Processing Record 34 of Set 6 | coolum beach
# Processing Record 35 of Set 6 | port hardy
# Processing Record 36 of Set 6 | swan hill
# Processing Record 37 of Set 6 | longyearbyen
# Processing Record 38 of Set 6 | beni
# Processing Record 39 of Set 6 | florianopolis
# Processing Record 40 of Set 6 | helena
# Processing Record 41 of Set 6 | nerang
# Processing Record 42 of Set 6 | batagay-alyta
# Processing Record 43 of Set 6 | campeche
# Processing Record 44 of Set 6 | manicore
# Processing Record 45 of Set 6 | viedma
# Processing Record 46 of Set 6 | burnie
# Processing Record 47 of Set 6 | thunder bay
# Processing Record 48 of Set 6 | hami
# Processing Record 49 of Set 6 | kondinskoye
# Processing Record 50 of Set 6 | jaunpur
# Processing Record 1 of Set 7 | raudeberg
# Processing Record 2 of Set 7 | guatire
# Processing Record 3 of Set 7 | kapurthala
# Processing Record 4 of Set 7 | genhe
# Processing Record 5 of Set 7 | hofn
# Processing Record 6 of Set 7 | khandagayty
# Processing Record 7 of Set 7 | hamilton
# Processing Record 8 of Set 7 | duncan
# Processing Record 9 of Set 7 | ankang
# Processing Record 10 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 7 | addi ugri
# City not found. Skipping...
# Processing Record 12 of Set 7 | yulara
# Processing Record 13 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 14 of Set 7 | bereznik
# Processing Record 15 of Set 7 | nova odesa
# Processing Record 16 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 7 | inirida
# Processing Record 18 of Set 7 | hambantota
# Processing Record 19 of Set 7 | sept-iles
# Processing Record 20 of Set 7 | tuatapere
# Processing Record 21 of Set 7 | wum
# Processing Record 22 of Set 7 | nouakchott
# Processing Record 23 of Set 7 | labuhan
# Processing Record 24 of Set 7 | san nicolas
# Processing Record 25 of Set 7 | teahupoo
# Processing Record 26 of Set 7 | yabelo
# Processing Record 27 of Set 7 | evensk
# Processing Record 28 of Set 7 | rawson
# Processing Record 29 of Set 7 | novodugino
# Processing Record 30 of Set 7 | banepa
# Processing Record 31 of Set 7 | alice springs
# Processing Record 32 of Set 7 | ushtobe
# Processing Record 33 of Set 7 | heihe
# Processing Record 34 of Set 7 | chifeng
# Processing Record 35 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 36 of Set 7 | honolulu
# Processing Record 37 of Set 7 | adrar
# Processing Record 38 of Set 7 | naze
# Processing Record 39 of Set 7 | flagstaff
# Processing Record 40 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 41 of Set 7 | lompoc
# Processing Record 42 of Set 7 | diamantino
# Processing Record 43 of Set 7 | ibra
# Processing Record 44 of Set 7 | anadyr
# Processing Record 45 of Set 7 | mahibadhoo
# Processing Record 46 of Set 7 | wadi maliz
# Processing Record 47 of Set 7 | yankton
# Processing Record 48 of Set 7 | biak
# Processing Record 49 of Set 7 | kalmunai
# Processing Record 50 of Set 7 | chilca
# Processing Record 1 of Set 8 | richmond
# Processing Record 2 of Set 8 | fengzhen
# Processing Record 3 of Set 8 | ornskoldsvik
# Processing Record 4 of Set 8 | porbandar
# Processing Record 5 of Set 8 | la ronge
# Processing Record 6 of Set 8 | sheridan
# Processing Record 7 of Set 8 | shingu
# Processing Record 8 of Set 8 | lixourion
# Processing Record 9 of Set 8 | kiunga
# Processing Record 10 of Set 8 | quime
# Processing Record 11 of Set 8 | mehamn
# Processing Record 12 of Set 8 | shalinskoye
# Processing Record 13 of Set 8 | ketchikan
# Processing Record 14 of Set 8 | fukue
# Processing Record 15 of Set 8 | andenes
# Processing Record 16 of Set 8 | salym
# Processing Record 17 of Set 8 | belmonte
# Processing Record 18 of Set 8 | coos bay
# Processing Record 19 of Set 8 | xinxiang
# Processing Record 20 of Set 8 | bolshoye selo
# Processing Record 21 of Set 8 | camacha
# Processing Record 22 of Set 8 | kasane
# Processing Record 23 of Set 8 | vila franca do campo
# Processing Record 24 of Set 8 | laguna
# Processing Record 25 of Set 8 | strezhevoy
# Processing Record 26 of Set 8 | jacmel
# Processing Record 27 of Set 8 | sinnamary
# Processing Record 28 of Set 8 | pochutla
# Processing Record 29 of Set 8 | galena park
# Processing Record 30 of Set 8 | nakusp
# Processing Record 31 of Set 8 | srednekolymsk
# Processing Record 32 of Set 8 | masindi
# Processing Record 33 of Set 8 | puerto madryn
# Processing Record 34 of Set 8 | nyurba
# Processing Record 35 of Set 8 | nenagh
# Processing Record 36 of Set 8 | general roca
# Processing Record 37 of Set 8 | broken hill
# Processing Record 38 of Set 8 | changping
# Processing Record 39 of Set 8 | northam
# Processing Record 40 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 41 of Set 8 | egvekinot
# Processing Record 42 of Set 8 | taoudenni
# Processing Record 43 of Set 8 | wilmington island
# Processing Record 44 of Set 8 | mutare
# Processing Record 45 of Set 8 | flers
# Processing Record 46 of Set 8 | russell
# Processing Record 47 of Set 8 | blue springs
# Processing Record 48 of Set 8 | champerico
# Processing Record 49 of Set 8 | ljubinje
# Processing Record 50 of Set 8 | costinesti
# Processing Record 1 of Set 9 | svetlaya
# Processing Record 2 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 9 | tupiza
# Processing Record 5 of Set 9 | gigmoto
# Processing Record 6 of Set 9 | gravdal
# Processing Record 7 of Set 9 | komsomolskiy
# Processing Record 8 of Set 9 | barra
# Processing Record 9 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 9 | lakatoro
# Processing Record 11 of Set 9 | maldonado
# Processing Record 12 of Set 9 | tual
# Processing Record 13 of Set 9 | eureka
# Processing Record 14 of Set 9 | sur
# Processing Record 15 of Set 9 | corumba
# Processing Record 16 of Set 9 | esna
# Processing Record 17 of Set 9 | rudnogorsk
# Processing Record 18 of Set 9 | port hedland
# Processing Record 19 of Set 9 | atasu
# Processing Record 20 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 9 | narsaq
# Processing Record 22 of Set 9 | coihaique
# Processing Record 23 of Set 9 | sioux lookout
# Processing Record 24 of Set 9 | odweyne
# Processing Record 25 of Set 9 | xai-xai
# Processing Record 26 of Set 9 | oktyabrskiy
# Processing Record 27 of Set 9 | arman
# Processing Record 28 of Set 9 | gimli
# Processing Record 29 of Set 9 | deputatskiy
# Processing Record 30 of Set 9 | bonthe
# Processing Record 31 of Set 9 | iqaluit
# Processing Record 32 of Set 9 | uberaba
# Processing Record 33 of Set 9 | itapecerica
# Processing Record 34 of Set 9 | mikonos
# City not found. Skipping...
# Processing Record 35 of Set 9 | east london
# Processing Record 36 of Set 9 | linxia
# Processing Record 37 of Set 9 | lodeynoye pole
# Processing Record 38 of Set 9 | kantunilkin
# Processing Record 39 of Set 9 | ambilobe
# Processing Record 40 of Set 9 | korla
# Processing Record 41 of Set 9 | ndende
# Processing Record 42 of Set 9 | gunnedah
# Processing Record 43 of Set 9 | namibe
# Processing Record 44 of Set 9 | bouafle
# Processing Record 45 of Set 9 | poopo
# Processing Record 46 of Set 9 | krasnoselkup
# Processing Record 47 of Set 9 | black river
# Processing Record 48 of Set 9 | necochea
# Processing Record 49 of Set 9 | nome
# Processing Record 50 of Set 9 | thinadhoo
# Processing Record 1 of Set 10 | sakata
# Processing Record 2 of Set 10 | kananga
# Processing Record 3 of Set 10 | mount darwin
# Processing Record 4 of Set 10 | deep river
# Processing Record 5 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | loukhi
# Processing Record 7 of Set 10 | north bend
# Processing Record 8 of Set 10 | quatre cocos
# Processing Record 9 of Set 10 | tanga
# Processing Record 10 of Set 10 | morwell
# Processing Record 11 of Set 10 | sindgi
# Processing Record 12 of Set 10 | lorengau
# Processing Record 13 of Set 10 | solnechnyy
# Processing Record 14 of Set 10 | tiznit
# Processing Record 15 of Set 10 | constitucion
# Processing Record 16 of Set 10 | kavaratti
# Processing Record 17 of Set 10 | benito juarez
# Processing Record 18 of Set 10 | aklavik
# Processing Record 19 of Set 10 | tautira
# Processing Record 20 of Set 10 | svetlogorsk
# Processing Record 21 of Set 10 | uyemskiy
# Processing Record 22 of Set 10 | bom jesus da lapa
# Processing Record 23 of Set 10 | los llanos de aridane
# Processing Record 24 of Set 10 | port blair
# Processing Record 25 of Set 10 | vaiusu
# Processing Record 26 of Set 10 | san carlos de bariloche
# Processing Record 27 of Set 10 | maceio
# Processing Record 28 of Set 10 | la asuncion
# Processing Record 29 of Set 10 | port hawkesbury
# Processing Record 30 of Set 10 | manokwari
# Processing Record 31 of Set 10 | palatka
# Processing Record 32 of Set 10 | sechura
# Processing Record 33 of Set 10 | clyde river
# Processing Record 34 of Set 10 | svetlyy
# Processing Record 35 of Set 10 | tarakan
# Processing Record 36 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 37 of Set 10 | alekseyevka
# Processing Record 38 of Set 10 | riyadh
# Processing Record 39 of Set 10 | cayenne
# Processing Record 40 of Set 10 | plettenberg bay
# Processing Record 41 of Set 10 | kastamonu
# Processing Record 42 of Set 10 | kaka
# Processing Record 43 of Set 10 | tokur
# Processing Record 44 of Set 10 | bulgan
# Processing Record 45 of Set 10 | baoshan
# Processing Record 46 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 47 of Set 10 | kamaishi
# Processing Record 48 of Set 10 | elko
# Processing Record 49 of Set 10 | gorom-gorom
# Processing Record 50 of Set 10 | shimonoseki
# Processing Record 1 of Set 11 | quelimane
# Processing Record 2 of Set 11 | atherton
# Processing Record 3 of Set 11 | broome
# Processing Record 4 of Set 11 | touros
# Processing Record 5 of Set 11 | ordzhonikidze
# Processing Record 6 of Set 11 | gaziantep
# Processing Record 7 of Set 11 | ust-nera
# Processing Record 8 of Set 11 | rafai
# Processing Record 9 of Set 11 | mampong
# Processing Record 10 of Set 11 | sungai besar
# Processing Record 11 of Set 11 | kalabo
# Processing Record 12 of Set 11 | bubaque
# Processing Record 13 of Set 11 | faya
# Processing Record 14 of Set 11 | washington
# Processing Record 15 of Set 11 | ossora
# Processing Record 16 of Set 11 | high level
# Processing Record 17 of Set 11 | karratha
# Processing Record 18 of Set 11 | saint-malo
# Processing Record 19 of Set 11 | yian
# City not found. Skipping...
# Processing Record 20 of Set 11 | kaeo
# Processing Record 21 of Set 11 | kasongo-lunda
# Processing Record 22 of Set 11 | saint-felicien
# Processing Record 23 of Set 11 | gotsu
# Processing Record 24 of Set 11 | gandajika
# Processing Record 25 of Set 11 | isakly
# Processing Record 26 of Set 11 | lata
# Processing Record 27 of Set 11 | rio grande
# Processing Record 28 of Set 11 | kyren
# Processing Record 29 of Set 11 | north bay
# Processing Record 30 of Set 11 | aasiaat
# Processing Record 31 of Set 11 | chumikan
# Processing Record 32 of Set 11 | murray bridge
# Processing Record 33 of Set 11 | tonj
# Processing Record 34 of Set 11 | jinchang
# Processing Record 35 of Set 11 | khandyga
# Processing Record 36 of Set 11 | kendari
# Processing Record 37 of Set 11 | amalapuram
# Processing Record 38 of Set 11 | the valley
# Processing Record 39 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 11 | ambon
# Processing Record 41 of Set 11 | biskamzha
# Processing Record 42 of Set 11 | portland
# Processing Record 43 of Set 11 | dickinson
# Processing Record 44 of Set 11 | ishinomaki
# Processing Record 45 of Set 11 | kathu
# Processing Record 46 of Set 11 | lakselv
# Processing Record 47 of Set 11 | malmyzh
# Processing Record 48 of Set 11 | xiongzhou
# Processing Record 49 of Set 11 | aksarka
# Processing Record 50 of Set 11 | deniliquin
# Processing Record 1 of Set 12 | salinopolis
# Processing Record 2 of Set 12 | bundaberg
# Processing Record 3 of Set 12 | klaksvik
# Processing Record 4 of Set 12 | selikhino
# Processing Record 5 of Set 12 | yakeshi
# Processing Record 6 of Set 12 | christchurch
# Processing Record 7 of Set 12 | khash
# Processing Record 8 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 9 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 10 of Set 12 | san lazaro
# Processing Record 11 of Set 12 | aitape
# Processing Record 12 of Set 12 | payo
# Processing Record 13 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 12 | malinovskiy
# Processing Record 15 of Set 12 | sinjar
# Processing Record 16 of Set 12 | krasnoye
# Processing Record 17 of Set 12 | ayagoz
# Processing Record 18 of Set 12 | ust-uda
# Processing Record 19 of Set 12 | kieta
# Processing Record 20 of Set 12 | arzgir
# Processing Record 21 of Set 12 | buchanan
# Processing Record 22 of Set 12 | kambove
# Processing Record 23 of Set 12 | faanui
# Processing Record 24 of Set 12 | huzhou
# Processing Record 25 of Set 12 | sedniv
# Processing Record 26 of Set 12 | barkly west
# Processing Record 27 of Set 12 | ostrovnoy
# Processing Record 28 of Set 12 | mbaiki
# Processing Record 29 of Set 12 | socastee
# Processing Record 30 of Set 12 | luderitz
# Processing Record 31 of Set 12 | saint-augustin
# Processing Record 32 of Set 12 | oranjestad
# Processing Record 33 of Set 12 | ponta delgada
# Processing Record 34 of Set 12 | srandakan
# Processing Record 35 of Set 12 | santa isabel do rio negro
# Processing Record 36 of Set 12 | maniitsoq
# Processing Record 37 of Set 12 | urumqi
# Processing Record 38 of Set 12 | canavieiras
# Processing Record 39 of Set 12 | chhatak
# Processing Record 40 of Set 12 | rantepao
# Processing Record 41 of Set 12 | dudinka
# Processing Record 42 of Set 12 | gouyave
# Processing Record 43 of Set 12 | toora-khem
# Processing Record 44 of Set 12 | sorland
# Processing Record 45 of Set 12 | nguruka
# Processing Record 46 of Set 12 | alofi
# Processing Record 47 of Set 12 | bandar maharani
# City not found. Skipping...
# Processing Record 48 of Set 12 | atikokan
# Processing Record 49 of Set 12 | duz
# City not found. Skipping...
# Processing Record 50 of Set 12 | caxito
# Processing Record 1 of Set 13 | san jeronimo
# Processing Record 2 of Set 13 | awjilah
# Processing Record 3 of Set 13 | zavitinsk
# Processing Record 4 of Set 13 | san cristobal
# Processing Record 5 of Set 13 | waingapu
# Processing Record 6 of Set 13 | bemidji
# Processing Record 7 of Set 13 | staunton
# Processing Record 8 of Set 13 | rapar
# Processing Record 9 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 10 of Set 13 | palu
# Processing Record 11 of Set 13 | nanortalik
# Processing Record 12 of Set 13 | namatanai
# Processing Record 13 of Set 13 | mikasa
# Processing Record 14 of Set 13 | madisonville
# Processing Record 15 of Set 13 | ardalstangen
# Processing Record 16 of Set 13 | bereda
# Processing Record 17 of Set 13 | muroto
# Processing Record 18 of Set 13 | camocim
# Processing Record 19 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 13 | point pedro
# Processing Record 21 of Set 13 | sinyavino
# Processing Record 22 of Set 13 | japura
# Processing Record 23 of Set 13 | toamasina
# Processing Record 24 of Set 13 | puerto escondido
# Processing Record 25 of Set 13 | la primavera
# Processing Record 26 of Set 13 | stantsionno-oyashinskiy
# Processing Record 27 of Set 13 | arlit
# Processing Record 28 of Set 13 | vao
# Processing Record 29 of Set 13 | randolph
# Processing Record 30 of Set 13 | correia pinto
# Processing Record 31 of Set 13 | chowchilla
# Processing Record 32 of Set 13 | makakilo city
# Processing Record 33 of Set 13 | roseburg
# Processing Record 34 of Set 13 | suzun
# Processing Record 35 of Set 13 | xining
# Processing Record 36 of Set 13 | ankara
# Processing Record 37 of Set 13 | sudak
# Processing Record 38 of Set 13 | antipino
# Processing Record 39 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 13 | mezen
# Processing Record 41 of Set 13 | cassia
# Processing Record 42 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 13 | tezu
# Processing Record 44 of Set 13 | clarksville
# Processing Record 45 of Set 13 | moscow
# Processing Record 46 of Set 13 | mackay
# Processing Record 47 of Set 13 | imeni poliny osipenko
# Processing Record 48 of Set 13 | tilichiki
# Processing Record 49 of Set 13 | tongliao
# Processing Record 50 of Set 13 | piacabucu
# Processing Record 1 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 14 | dakar
# Processing Record 3 of Set 14 | sal rei
# Processing Record 4 of Set 14 | phetchabun
# Processing Record 5 of Set 14 | marica
# Processing Record 6 of Set 14 | warman
# Processing Record 7 of Set 14 | beringovskiy
# Processing Record 8 of Set 14 | nishihara
# Processing Record 9 of Set 14 | baijiantan
# Processing Record 10 of Set 14 | tamandare
# Processing Record 11 of Set 14 | skibbereen
# Processing Record 12 of Set 14 | muli
# Processing Record 13 of Set 14 | bentiu
# Processing Record 14 of Set 14 | marsh harbour
# Processing Record 15 of Set 14 | verkhnetulomskiy
# Processing Record 16 of Set 14 | oktyabrskoye
# Processing Record 17 of Set 14 | yarada
# Processing Record 18 of Set 14 | enterprise
# Processing Record 19 of Set 14 | cairns
# Processing Record 20 of Set 14 | ternova
# Processing Record 21 of Set 14 | muzaffarabad
# Processing Record 22 of Set 14 | aksha
# Processing Record 23 of Set 14 | nara
# Processing Record 24 of Set 14 | bardiyah
# Processing Record 25 of Set 14 | yar-sale
# Processing Record 26 of Set 14 | pipri
# Processing Record 27 of Set 14 | payakumbuh
# Processing Record 28 of Set 14 | yerbogachen
# Processing Record 29 of Set 14 | padilla
# Processing Record 30 of Set 14 | puerto asis
# Processing Record 31 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 14 | las vegas
# Processing Record 33 of Set 14 | manta
# Processing Record 34 of Set 14 | brandon
# Processing Record 35 of Set 14 | sotuta
# Processing Record 36 of Set 14 | zambezi
# Processing Record 37 of Set 14 | newport
# Processing Record 38 of Set 14 | karasjok
# Processing Record 39 of Set 14 | cortes
# Processing Record 40 of Set 14 | puerto colombia
# Processing Record 41 of Set 14 | saint-joseph
# Processing Record 42 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 14 | ucluelet
# Processing Record 44 of Set 14 | da nang
# Processing Record 45 of Set 14 | anaco
# Processing Record 46 of Set 14 | marzuq
# Processing Record 47 of Set 14 | sao gabriel da cachoeira
# Processing Record 48 of Set 14 | bocaranga
# City not found. Skipping...
# Processing Record 49 of Set 14 | saint anthony
# Processing Record 50 of Set 14 | stornoway
# Processing Record 1 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 2 of Set 15 | sangmelima
# Processing Record 3 of Set 15 | olafsvik
# Processing Record 4 of Set 15 | nzega
# Processing Record 5 of Set 15 | cam ranh
# Processing Record 6 of Set 15 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 7 of Set 15 | tutubigan
# Processing Record 8 of Set 15 | muros
# Processing Record 9 of Set 15 | chunoyar
# Processing Record 10 of Set 15 | mancio lima
# Processing Record 11 of Set 15 | hervey bay
# Processing Record 12 of Set 15 | obera
# Processing Record 13 of Set 15 | tabas
# Processing Record 14 of Set 15 | beja
# Processing Record 15 of Set 15 | coahuayana
# Processing Record 16 of Set 15 | boyolangu
# Processing Record 17 of Set 15 | meulaboh
# Processing Record 18 of Set 15 | vostok
# Processing Record 19 of Set 15 | umm kaddadah
# Processing Record 20 of Set 15 | uvat
# Processing Record 21 of Set 15 | cortez
# Processing Record 22 of Set 15 | gazli
# Processing Record 23 of Set 15 | coruripe
# Processing Record 24 of Set 15 | henties bay
# Processing Record 25 of Set 15 | salvador
# Processing Record 26 of Set 15 | cabedelo
# Processing Record 27 of Set 15 | enugu
# Processing Record 28 of Set 15 | iracoubo
# Processing Record 29 of Set 15 | san isidro
# Processing Record 30 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 15 | limon
# Processing Record 32 of Set 15 | kloulklubed
# Processing Record 33 of Set 15 | kaniama
# Processing Record 34 of Set 15 | elat
# Processing Record 35 of Set 15 | san rafael
# Processing Record 36 of Set 15 | saint-agapit
# Processing Record 37 of Set 15 | sivaki
# Processing Record 38 of Set 15 | kholodnyy
# Processing Record 39 of Set 15 | sladkovo
# Processing Record 40 of Set 15 | kibala
# Processing Record 41 of Set 15 | matagami
# Processing Record 42 of Set 15 | lepe
# Processing Record 43 of Set 15 | ormara
# Processing Record 44 of Set 15 | krasnyy chikoy
# Processing Record 45 of Set 15 | nuuk
# Processing Record 46 of Set 15 | cabra
# Processing Record 47 of Set 15 | tateyama
# Processing Record 48 of Set 15 | amapala
# Processing Record 49 of Set 15 | batsfjord
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 693

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Tiksi      RU  71.69  128.87     -2.56        89          44
# 1   Provideniya      RU  64.38 -173.30     23.00        62          40
# 2       Colares      PT  38.80   -9.45     63.00        88           9
# 3       Mataura      NZ -46.19  168.86     54.00        68           0
# 4         Airai      TL  -8.93  125.41     74.66        61          91
# 5  Punta Arenas      CL -53.15  -70.92     50.00        81           0
# 6      Balaguer      ES  41.79    0.81     46.40        93           0
# 7  San Patricio      US  28.02  -97.52     64.40        63           1
# 8        Kodiak      US  57.79 -152.41     30.20        33          90
# 9    Nikolskoye      RU  59.70   30.79     33.80        97          90
#
#    Wind Speed Current Description
# 0        6.67    scattered clouds
# 1        3.58          heavy snow
# 2        3.00           clear sky
# 3        7.00           clear sky
# 4        2.75     overcast clouds
# 5        6.93           clear sky
# 6        1.12           clear sky
# 7       11.41           clear sky
# 8       12.75     overcast clouds
# 9        8.95     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.isnull().sum()
# Out:
# City                   0
# Country                0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64
